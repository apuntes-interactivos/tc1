# %%
import lcapy as ly

ej=ly.Circuit()


ej.add("""
Vi _a _f ; down 
R _a _b 10e3; right, l=$10 k \Omega$
C1 _b _c 10e-6; right, l=$10 \mu F$
C2 _c _d 5e-6; down=1.5, v=V_o, l=$ 5 \mu F$
W1 _d _f; left=2
""")

ej.draw()

# %% [markdown]
# Dado el siguiente circuito:
#
# a) Representar en dominio de la frecuencia compleja s
#
# b) Obtener la función de transferencia
#
# c) Encontrar la respuesta al impulso

# %%
import lcapy as ly

ej2=ly.Circuit()


ej2.add("""
V _a _f ; down ,l=$v_i(t)$
R _a _b 10e3; right, l=$10 k \Omega$
C1 _b _c 10e-6; right, l=$10 \mu F$
R2 _c _d 5e3; down=1.5, v=v_o(t), l=$5k \Omega $
W1 _d _f; left=2
""")

ej2.draw()

# %% [markdown]
# Dado el siguiente circuito:
#
# a) Representar en dominio de la frecuencia compleja s
#
# b) Obtener la función de transferencia
#
# c) Encontrar la respuesta al escalón

# %%
ej3 = ly.Circuit()
ej3.add("""
I _a _b ;down, l=$i_i(t)$
W1 _a _c; right
W2 _b _d;right
R1 _c _d; down,l=$50 \Omega $
W3 _c _e;right
W4 _d _f; right
L1 _e _f; down, l=$0.2 Hy$
W5 _e _g; right
W6 _f _h; right
L2 _g _h; down,l=$0.4 Hy$, i=$i_0(t)$
""")

ej3.draw()
